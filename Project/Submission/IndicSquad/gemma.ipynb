# %%
import json
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
import json
import csv
import torch
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
from huggingface_hub import login
login(new_session=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="google/gemma-2-2b")
# Out:
# config.json:   0%|          | 0.00/818 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/481M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
model_name = "google/gemma-2-2b-it"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)

device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/241M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **HINDI CLEANING**

# %%
import json

# Paths
english_clean_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/english_cleaned.json"
language_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/hindi_cleaned.json"
output_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/hindi_cleaned-filtered.json"

# -----------------------------
# 1. Load cleaned English data & extract valid IDs
# -----------------------------
with open(english_clean_path, "r", encoding="utf-8") as f:
    eng = json.load(f)

valid_ids = set()

# English is SQuAD formatted → extract ids from paragraphs/qas
for article in eng["data"]:
    for para in article["paragraphs"]:
        for qa in para["qas"]:
            valid_ids.add(qa["id"])

print("Valid English IDs:", len(valid_ids))

# -----------------------------
# 2. Load target language file (Hindi)
# -----------------------------
with open(language_path, "r", encoding="utf-8") as f:
    lang = json.load(f)

filtered_items = []

# -----------------------------
# 3. FLAT format filtering
# -----------------------------
for item in lang["data"]:

    if not isinstance(item, dict):
        continue

    qid = item.get("id", None)

    if qid in valid_ids:
        filtered_items.append(item)

print("Filtered items:", len(filtered_items))

# -----------------------------
# 4. Save output
# -----------------------------
output = {
    "version": lang.get("version", "v1.1"),
    "data": filtered_items
}

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print("Filtered dataset saved to:", output_path)
# Out:
# Valid English IDs: 5928
# Filtered items: 5928
# Filtered dataset saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/hindi_cleaned-filtered.json

# %% [markdown]
# **KANNADA CLEANING**

# %%
import json

# Paths
english_clean_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/english_cleaned.json"
language_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/kannada_cleaned.json"
output_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/kannada_cleaned-filtered.json"

# -----------------------------
# 1. Load cleaned English data & extract valid IDs
# -----------------------------
with open(english_clean_path, "r", encoding="utf-8") as f:
    eng = json.load(f)

valid_ids = set()

# English is SQuAD formatted → extract ids from paragraphs/qas
for article in eng["data"]:
    for para in article["paragraphs"]:
        for qa in para["qas"]:
            valid_ids.add(qa["id"])

print("Valid English IDs:", len(valid_ids))

# -----------------------------
# 2. Load target language file (Hindi)
# -----------------------------
with open(language_path, "r", encoding="utf-8") as f:
    lang = json.load(f)

filtered_items = []

# -----------------------------
# 3. FLAT format filtering
# -----------------------------
for item in lang["data"]:

    if not isinstance(item, dict):
        continue

    qid = item.get("id", None)

    if qid in valid_ids:
        filtered_items.append(item)

print("Filtered items:", len(filtered_items))

# -----------------------------
# 4. Save output
# -----------------------------
output = {
    "version": lang.get("version", "v1.1"),
    "data": filtered_items
}

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print("Filtered dataset saved to:", output_path)
# Out:
# Valid English IDs: 5928
# Filtered items: 5928
# Filtered dataset saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/kannada_cleaned-filtered.json

# %% [markdown]
# **TAMIL CLEANED**

# %%
import json

# Paths
english_clean_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/english_cleaned.json"
language_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/tamil_cleaned.json"
output_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/tamil_cleaned-filtered.json"

# -----------------------------
# 1. Load cleaned English data & extract valid IDs
# -----------------------------
with open(english_clean_path, "r", encoding="utf-8") as f:
    eng = json.load(f)

valid_ids = set()

# English is SQuAD formatted → extract ids from paragraphs/qas
for article in eng["data"]:
    for para in article["paragraphs"]:
        for qa in para["qas"]:
            valid_ids.add(qa["id"])

print("Valid English IDs:", len(valid_ids))

# -----------------------------
# 2. Load target language file (Hindi)
# -----------------------------
with open(language_path, "r", encoding="utf-8") as f:
    lang = json.load(f)

filtered_items = []

# -----------------------------
# 3. FLAT format filtering
# -----------------------------
for item in lang["data"]:

    if not isinstance(item, dict):
        continue

    qid = item.get("id", None)

    if qid in valid_ids:
        filtered_items.append(item)

print("Filtered items:", len(filtered_items))

# -----------------------------
# 4. Save output
# -----------------------------
output = {
    "version": lang.get("version", "v1.1"),
    "data": filtered_items
}

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print("Filtered dataset saved to:", output_path)
# Out:
# Valid English IDs: 5928
# Filtered items: 5928
# Filtered dataset saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/tamil_cleaned-filtered.json

# %% [markdown]
# **MARATHI CLEANED**

# %%
import json

# Paths
english_clean_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/english_cleaned.json"
language_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned.json"
output_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned-filtered-1f.json"

# -----------------------------
# 1. Load cleaned English data & extract valid IDs
# -----------------------------
with open(english_clean_path, "r", encoding="utf-8") as f:
    eng = json.load(f)

valid_ids = set()

# English is SQuAD formatted → extract ids from paragraphs/qas
for article in eng["data"]:
    for para in article["paragraphs"]:
        for qa in para["qas"]:
            valid_ids.add(qa["id"])

print("Valid English IDs:", len(valid_ids))

# -----------------------------
# 2. Load target language file (Hindi)
# -----------------------------
with open(language_path, "r", encoding="utf-8") as f:
    lang = json.load(f)

filtered_items = []

# -----------------------------
# 3. FLAT format filtering
# -----------------------------
for item in lang["data"]:

    if not isinstance(item, dict):
        continue

    qid = item.get("id", None)

    if qid in valid_ids:
        filtered_items.append(item)

print("Filtered items:", len(filtered_items))

# -----------------------------
# 4. Save output
# -----------------------------
output = {
    "version": lang.get("version", "v1.1"),
    "data": filtered_items
}

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print("Filtered dataset saved to:", output_path)
# Out:
# Valid English IDs: 5928
# Filtered items: 0
# Filtered dataset saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned-filtered-1f.json

# %% [markdown]
# **GEMMA-ENGLISH**

# %%
json_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/english_cleaned.json"
output_csv = "/content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/GEMMA/gemma_english_batched.csv"

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

all_qas = []
for article in data["data"]:
    for para in article["paragraphs"]:
        context = para["context"]
        for qa in para["qas"]:
            all_qas.append({
                "id": qa["id"],
                "question": qa["question"],
                "context": context,
                "expected": qa["answers"][0]["text"]
            })

print(f"Total questions: {len(all_qas)}")
# Out:
# Total questions: 5928

# %%
BATCH_SIZE = 8

with open(output_csv, "w", newline='', encoding="utf-8") as f_out:
    writer = csv.writer(f_out)
    writer.writerow(["id", "model_answer", "expected_answer"])

    num_batches = (len(all_qas) + BATCH_SIZE - 1) // BATCH_SIZE

    for batch_idx in tqdm(range(num_batches), desc="Generating English QA with Gemma (batched)"):

        # Free GPU memory before next batch
        torch.cuda.empty_cache()

        batch = all_qas[batch_idx * BATCH_SIZE : (batch_idx+1) * BATCH_SIZE]

        prompts = [
            f"Context: {entry['context']}\nQuestion: {entry['question']}\nAnswer:"
            for entry in batch
        ]

        # Tokenize batch
        inputs = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=1024
        ).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=64,      # reduced
                do_sample=False,
                pad_token_id=tokenizer.pad_token_id
            )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        for i, entry in enumerate(batch):
            text = decoded[i]
            generated = text.replace(prompts[i], "").strip()
            generated = generated.split("\n")[0].strip()

            writer.writerow([entry["id"], generated, entry["expected"]])

print("Done! CSV saved at:", output_csv)
# Out:
# Generating English QA with Gemma (batched): 100%|██████████| 741/741 [39:01<00:00,  3.16s/it]
# Done! CSV saved at: /content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/GEMMA/gemma_english_batched.csv

# %% [markdown]
# **KANNADA**

# %%
json_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/kannada_cleaned-filtered.json"
output_csv = "/content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_kannada.csv"

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

all_qas = []

for item in data["data"]:
    if not isinstance(item, dict):
        continue

    answers = item.get("answers", {}).get("text", [])
    if not answers:
        continue

    all_qas.append({
        "id": item["id"],
        "question": item["question"],
        "context": item["context"],
        "expected": answers[0]
    })

print(f"Total Kannada questions: {len(all_qas)}")
# Out:
# Total Kannada questions: 5928

# %%
BATCH_SIZE = 8

with open(output_csv, "w", newline="", encoding="utf-8") as f_out:
    writer = csv.writer(f_out)
    writer.writerow(["id", "model_answer", "expected_answer"])

    num_batches = (len(all_qas) + BATCH_SIZE - 1) // BATCH_SIZE

    for batch_idx in tqdm(range(num_batches), desc="Generating Kannada QA with Gemma"):

        torch.cuda.empty_cache()  # crucial

        batch = all_qas[batch_idx * BATCH_SIZE : (batch_idx + 1) * BATCH_SIZE]

        prompts = [
            f"Context: {e['context']}\nQuestion: {e['question']}\nAnswer:"
            for e in batch
        ]

        inputs = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=1024
        ).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=64,
                do_sample=False,
                pad_token_id=tokenizer.pad_token_id
            )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        for i, entry in enumerate(batch):
            generated = decoded[i].replace(prompts[i], "").strip()
            generated = generated.split("\n")[0].strip()

            writer.writerow([
                entry["id"],
                generated,
                entry["expected"]
            ])

print("✅ Kannada Gemma CSV saved to:", output_csv)
# Out:
# Generating Kannada QA with Gemma: 100%|██████████| 741/741 [43:42<00:00,  3.54s/it]
# ✅ Kannada Gemma CSV saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_kannada.csv

# %% [markdown]
# TAMIL

# %%
json_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/tamil_cleaned-filtered.json"
output_csv = "/content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_tamil.csv"

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

all_qas = []

for item in data["data"]:
    if not isinstance(item, dict):
        continue

    answers = item.get("answers", {}).get("text", [])
    if not answers:
        continue

    all_qas.append({
        "id": item["id"],
        "question": item["question"],
        "context": item["context"],
        "expected": answers[0]
    })

print(f"Total Tamil questions: {len(all_qas)}")
# Out:
# Total Tamil questions: 5928

# %%
BATCH_SIZE = 8

with open(output_csv, "w", newline="", encoding="utf-8") as f_out:
    writer = csv.writer(f_out)
    writer.writerow(["id", "model_answer", "expected_answer"])

    num_batches = (len(all_qas) + BATCH_SIZE - 1) // BATCH_SIZE

    for batch_idx in tqdm(range(num_batches), desc="Generating Tamil QA with Gemma"):

        torch.cuda.empty_cache()  # critical

        batch = all_qas[batch_idx * BATCH_SIZE : (batch_idx + 1) * BATCH_SIZE]

        prompts = [
            f"Context: {e['context']}\nQuestion: {e['question']}\nAnswer:"
            for e in batch
        ]

        inputs = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=1024
        ).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=64,
                do_sample=False,
                pad_token_id=tokenizer.pad_token_id
            )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        for i, entry in enumerate(batch):
            generated = decoded[i].replace(prompts[i], "").strip()
            generated = generated.split("\n")[0].strip()

            writer.writerow([
                entry["id"],
                generated,
                entry["expected"]
            ])

print("✅ Tamil Gemma CSV saved to:", output_csv)
# Out:
# Generating Tamil QA with Gemma: 100%|██████████| 741/741 [42:45<00:00,  3.46s/it]
# ✅ Tamil Gemma CSV saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_tamil.csv

# %% [markdown]
# HINDI

# %%
json_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/hindi_cleaned-filtered.json"
output_csv = "/content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_hindi-1f.csv"

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

all_qas = []

for item in data["data"]:
    if not isinstance(item, dict):
        continue

    answers = item.get("answers", {}).get("text", [])
    if not answers:
        continue

    all_qas.append({
        "id": item["id"],
        "question": item["question"],
        "context": item["context"],
        "expected": answers[0]
    })

print(f"Total Hindi questions: {len(all_qas)}")
# Out:
# Total Hindi questions: 5928

# %%
BATCH_SIZE = 8
device = "cuda" if torch.cuda.is_available() else "cpu"

with open(output_csv, "w", newline="", encoding="utf-8") as f_out:
    writer = csv.writer(f_out)
    writer.writerow(["id", "model_answer", "expected_answer"])

    num_batches = (len(all_qas) + BATCH_SIZE - 1) // BATCH_SIZE

    for batch_idx in tqdm(range(num_batches), desc="Generating Hindi QA with Gemma"):

        torch.cuda.empty_cache()  # CRITICAL

        batch = all_qas[batch_idx * BATCH_SIZE : (batch_idx + 1) * BATCH_SIZE]

        prompts = [
            f"Context: {e['context']}\nQuestion: {e['question']}\nAnswer:"
            for e in batch
        ]

        inputs = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=1024
        ).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=64,
                do_sample=False,
                pad_token_id=tokenizer.pad_token_id
            )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        for i, entry in enumerate(batch):
            generated = decoded[i].replace(prompts[i], "").strip()
            generated = generated.split("\n")[0].strip()

            writer.writerow([
                entry["id"],
                generated,
                entry["expected"]
            ])

print("✅ Hindi Gemma CSV saved to:", output_csv)
# Out:
# Generating Hindi QA with Gemma: 100%|██████████| 741/741 [39:42<00:00,  3.22s/it]
# ✅ Hindi Gemma CSV saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_hindi-1f.csv

# %% [markdown]
# **Marathi**

# %%
import json

# Paths
english_clean_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/english_cleaned.json"
language_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned.json"
output_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned-filtered-1f.json"

# -----------------------------
# 1. Load cleaned English data & extract valid IDs
# -----------------------------
with open(english_clean_path, "r", encoding="utf-8") as f:
    eng = json.load(f)

valid_ids = set()
for article in eng["data"]:
    for para in article["paragraphs"]:
        for qa in para["qas"]:
            valid_ids.add(qa["id"])

print("Valid English IDs:", len(valid_ids))  # should be 5928

# -----------------------------
# 2. Load Marathi data (NESTED FORMAT)
# -----------------------------
with open(language_path, "r", encoding="utf-8") as f:
    lang = json.load(f)

marathi_items = lang["data"]["data"]   # <-- IMPORTANT FIX

filtered_items = []

# -----------------------------
# 3. Filter using English IDs
# -----------------------------
for item in marathi_items:
    if item.get("id") in valid_ids:
        filtered_items.append(item)

print("Filtered Marathi questions:", len(filtered_items))

# -----------------------------
# 4. Save output (KEEP SAME STRUCTURE)
# -----------------------------
output = {
    "version": lang.get("version", "v1.1"),
    "data": {
        "data": filtered_items
    }
}

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print("Filtered dataset saved to:", output_path)
# Out:
# Valid English IDs: 5928
# Filtered Marathi questions: 5928
# Filtered dataset saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned-filtered-1f.json

# %%
json_path = "/content/drive/MyDrive/Project/Dataset/IndicSquad/cleaned_data/marathi_cleaned-filtered-1f.json"
output_csv = "/content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_marathi.csv"

import json


with open(json_path, "r", encoding="utf-8") as f:
    raw = json.load(f)

# 🔑 Correct level
items = raw["data"]["data"]

all_qas = []

for item in items:
    answers = item.get("answers", {}).get("text", [])
    if not answers:
        continue

    all_qas.append({
        "id": item["id"],
        "question": item["question"],
        "context": item["context"],
        "expected": answers[0]
    })

print(f"Total Marathi questions: {len(all_qas)}")
# Out:
# Total Marathi questions: 5928

# %%
BATCH_SIZE = 8
device = "cuda" if torch.cuda.is_available() else "cpu"

with open(output_csv, "w", newline="", encoding="utf-8") as f_out:
    writer = csv.writer(f_out)
    writer.writerow(["id", "model_answer", "expected_answer"])

    num_batches = (len(all_qas) + BATCH_SIZE - 1) // BATCH_SIZE

    for batch_idx in tqdm(range(num_batches), desc="Generating Marathi QA with Gemma"):

        torch.cuda.empty_cache()  # IMPORTANT

        batch = all_qas[batch_idx * BATCH_SIZE : (batch_idx + 1) * BATCH_SIZE]

        prompts = [
            f"Context: {e['context']}\nQuestion: {e['question']}\nAnswer:"
            for e in batch
        ]

        inputs = tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=1024
        ).to(device)

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=64,
                do_sample=False,
                pad_token_id=tokenizer.pad_token_id
            )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)

        for i, entry in enumerate(batch):
            generated = decoded[i].replace(prompts[i], "").strip()
            generated = generated.split("\n")[0].strip()

            writer.writerow([
                entry["id"],
                generated,
                entry["expected"]
            ])

print("✅ Marathi Gemma CSV saved to:", output_csv)
# Out:
# Generating Marathi QA with Gemma: 100%|██████████| 741/741 [41:59<00:00,  3.40s/it]
# ✅ Marathi Gemma CSV saved to: /content/drive/MyDrive/Project/Dataset/IndicSquad/OUTPUTS/gemma_marathi.csv
